# %%
from Road import Road, RoadState

# %%
road_generator = Road(car_generator=True)
road_1 = Road()
road_2 = Road()

# %%
print(road_generator)
print(road_1)
print(road_2)
# Out:
# Road ID: 0,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0

# %%
NOF_iter = 5

for i in range(NOF_iter):
    print(f"Iteration {i+1} of {NOF_iter}")
 
    road_generator.DEVS_send_event(None, road_1)
    road_1.DEVS_send_event(road_generator, road_2)
    road_2.DEVS_send_event(road_1, None)


    road_generator.DEVS_process_event()
    road_1.DEVS_process_event()     
    road_2.DEVS_process_event()

    print(road_generator)
    print(road_1)
    print(road_2)

    road_generator.DEVS_modify_state()
    road_1.DEVS_modify_state()
    road_2.DEVS_modify_state()

    print(road_generator)
    print(road_1)
    print(road_2)
    print("--------------------------------------------------")
# Out:
# Iteration 1 of 5
# Road ID: 0,t 0, Pos vehicles: [5, None, None, None]  State: Ssend
#                         Head: 0 Tail: 1
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 0,t 1.5, Pos vehicles: [5, None, None, None]  State: Ssend
#                         Head: 0 Tail: 1
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 1.5, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# --------------------------------------------------
# Iteration 2 of 5
# Road ID: 0,t 1.5, Pos vehicles: [5, 5, None, None]  State: Ssend
#                         Head: 0 Tail: 2
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 1.5, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.5, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 0,t 1.9, Pos vehicles: [20.0, 16, None, None]  State: Ssend
#                         Head: 0 Tail: 2
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 1.9, Previous global time: 1.5
#
# Road ID: 1,t 1.5, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.5, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# --------------------------------------------------
# Iteration 3 of 5
# Road ID: 0,t 1.9, Pos vehicles: [20.0, 16, 5, None]  State: Ssend
#                         Head: 0 Tail: 3
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 1.9, Previous global time: 1.5
#
# Road ID: 1,t 1.5, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.9, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 0,t 2.3, Pos vehicles: [20, 16, 9.0, None]  State: Ssend
#                         Head: 0 Tail: 3
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 2.3, Previous global time: 1.9
#
# Road ID: 1,t 1.9, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.9, Next road state buffer: Free
#                         Max global time: 1.5, Previous global time: 1.5
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# --------------------------------------------------
# Iteration 4 of 5
# Road ID: 0,t 2.3, Pos vehicles: [20, 16, 9.0, None]  State: Ssend
#                         Head: 0 Tail: 3
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 2.3, Previous global time: 1.9
#
# Road ID: 1,t 1.9, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 2.3, Next road state buffer: Free
#                         Max global time: 1.5, Previous global time: 1.5
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.5, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 0,t 2.6999999999999997, Pos vehicles: [20, 16, 12, None]  State: Ssend
#                         Head: 0 Tail: 3
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 2.6999999999999997, Previous global time: 2.3
#
# Road ID: 1,t 2.3, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 2.3, Next road state buffer: Free
#                         Max global time: 1.9, Previous global time: 1.9
#
# Road ID: 2,t 1.5, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.5, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# --------------------------------------------------
# Iteration 5 of 5
# Road ID: 0,t 2.6999999999999997, Pos vehicles: [20, 16, 12, None]  State: Ssend
#                         Head: 0 Tail: 3
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 2.6999999999999997, Previous global time: 2.3
#
# Road ID: 1,t 2.3, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 2.6999999999999997, Next road state buffer: Free
#                         Max global time: 1.9, Previous global time: 1.9
#
# Road ID: 2,t 1.5, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.9, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 0,t 3.0999999999999996, Pos vehicles: [20, 16, 12, None]  State: Ssend
#                         Head: 0 Tail: 3
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 3.0999999999999996, Previous global time: 2.6999999999999997
#
# Road ID: 1,t 2.6999999999999997, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 2.6999999999999997, Next road state buffer: Free
#                         Max global time: 2.3, Previous global time: 2.3
#
# Road ID: 2,t 1.9, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.9, Next road state buffer: None
#                         Max global time: 1.5, Previous global time: 1.5
#
# --------------------------------------------------

# %%
from Road import Road, RoadState

road_generator = Road(car_generator=True)
road_1 = Road()
road_2 = Road()

print(road_generator)
print(road_1)
print(road_2)
print("------------------------DEVS 3--------------------------")
road_generator.DEVS_send_event(None, road_1)
road_1.DEVS_send_event(road_generator, road_2)
road_2.DEVS_send_event(road_1, None)


print(road_generator)
print(road_1)
print(road_2)
print("------------------------DEVS 5---------------------------")

road_generator.DEVS_process_event()
road_1.DEVS_process_event()     
road_2.DEVS_process_event()

print(road_generator)
print(road_1)
print(road_2)
print("----------------------DEVS 6----------------------------")
road_generator.DEVS_modify_state()
road_1.DEVS_modify_state()
road_2.DEVS_modify_state()
print(road_generator)
print(road_1)
print(road_2)
print("--------------------------------------------------")
# Out:
# Road ID: 0,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ------------------------DEVS 3--------------------------
# Road ID: 0,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: So
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ------------------------DEVS 5---------------------------
# time to complete for road 0: [], global_t: 0
# time to complete for road 1: [], global_t: 0
# time to complete for road 2: [], global_t: 0
# Road ID: 0,t 0, Pos vehicles: [5, None, None, None]  State: Ssend
#                         Head: 0 Tail: 1
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ----------------------DEVS 6----------------------------
# Road ID: 0,t 0, Pos vehicles: [5, None, None, None]  State: Ssend
#                         Head: 0 Tail: 1
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# --------------------------------------------------

# %%
print(road_generator)
print(road_1)
print(road_2)
print("------------------------DEVS 3--------------------------")
road_generator.DEVS_send_event(None, road_1)
road_1.DEVS_send_event(road_generator, road_2)
road_2.DEVS_send_event(road_1, None)


print(road_generator)
print(road_1)
print(road_2)
print("------------------------DEVS 5---------------------------")

road_generator.DEVS_process_event()
road_1.DEVS_process_event()     
road_2.DEVS_process_event()

print(road_generator)
print(road_1)
print(road_2)
print("----------------------DEVS 6----------------------------")
road_generator.DEVS_modify_state()
road_1.DEVS_modify_state()
road_2.DEVS_modify_state()
print(road_generator)
print(road_1)
print(road_2)
print("--------------------------------------------------")
# Out:
# Road ID: 0,t 0, Pos vehicles: [5, None, None, None]  State: Ssend
#                         Head: 0 Tail: 1
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ------------------------DEVS 3--------------------------
# Road ID: 0,t 0, Pos vehicles: [5, None, None, None]  State: Ssend
#                         Head: 0 Tail: 1
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ------------------------DEVS 5---------------------------
# time to complete for road 0: [1.5], global_t: 0
# time to complete for road 1: [], global_t: 0
# time to complete for road 2: [], global_t: 0
# Road ID: 0,t 1.5, Pos vehicles: [20.0, 5, None, None]  State: Ssend
#                         Head: 0 Tail: 2
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 1.5, Previous global time: 1.5
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ----------------------DEVS 6----------------------------
# Road ID: 0,t 1.5, Pos vehicles: [20.0, 5, None, None]  State: Ssend
#                         Head: 0 Tail: 2
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 1.5, Previous global time: 1.5
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# --------------------------------------------------

# %%
print(road_generator)
print(road_1)
print(road_2)
print("------------------------DEVS 3--------------------------")
road_generator.DEVS_send_event(None, road_1)
road_1.DEVS_send_event(road_generator, road_2)
road_2.DEVS_send_event(road_1, None)


print(road_generator)
print(road_1)
print(road_2)
print("------------------------DEVS 5---------------------------")

road_generator.DEVS_process_event()
road_1.DEVS_process_event()     
road_2.DEVS_process_event()

print(road_generator)
print(road_1)
print(road_2)
print("----------------------DEVS 6----------------------------")
road_generator.DEVS_modify_state()
road_1.DEVS_modify_state()
road_2.DEVS_modify_state()
print(road_generator)
print(road_1)
print(road_2)
print("--------------------------------------------------")
# Out:
# Road ID: 0,t 1.5, Pos vehicles: [20.0, 5, None, None]  State: Ssend
#                         Head: 0 Tail: 2
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 1.5, Previous global time: 1.5
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ------------------------DEVS 3--------------------------
# Road ID: 0,t 1.5, Pos vehicles: [20.0, 5, None, None]  State: Ssend
#                         Head: 0 Tail: 2
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 1.5, Previous global time: 1.5
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.5, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ------------------------DEVS 5---------------------------
# time to complete for road 0: [1.5], global_t: 1.5
# time to complete for road 1: [], global_t: 0
# time to complete for road 2: [], global_t: 0
# Road ID: 0,t 1.5, Pos vehicles: [20.0, 5, 5, None]  State: Ssend
#                         Head: 0 Tail: 3
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 3.0, Previous global time: 1.5
#
# Road ID: 1,t 0, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.5, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# ----------------------DEVS 6----------------------------
# Road ID: 0,t 3.0, Pos vehicles: [20.0, 5, 5, None]  State: Ssend
#                         Head: 0 Tail: 3
#                         Previous road vehicle buffer: None, Previous road min time buffer: None, Next road state buffer: Free
#                         Max global time: 3.0, Previous global time: 1.5
#
# Road ID: 1,t 1.5, Pos vehicles: [None, None, None, None]  State: Ssend
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 1.5, Next road state buffer: Free
#                         Max global time: 0, Previous global time: 0
#
# Road ID: 2,t 0, Pos vehicles: [None, None, None, None]  State: Sno
#                         Head: 0 Tail: 0
#                         Previous road vehicle buffer: None, Previous road min time buffer: 0, Next road state buffer: None
#                         Max global time: 0, Previous global time: 0
#
# --------------------------------------------------
